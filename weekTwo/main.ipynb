C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 47                              1               0                   8
# 48                              1               0                   1
# 49                              1               0                   8
# 124                             3               1                   8
# 125                             3               1                   5
# 126                             3               1                   1
# 147                             2               1                  13
# 148                             2               1                   5
# 149                             2               1                   5
# 150                             2               1                   5
# 151                             2               1                   8
# 163                             3               1                   5
# 219                             1               0                   8
# 297                             1               1                   8
# 298                             1               1                   8
# 406                             1               0                   1
# 407                             1               0                   8
# 454                             1               1                   8
# 457                             1               0                   1
# 458                             1               0                   5
# 459                             1               0                   1
# 460                             1               0                   5
# 461                             1               0                   1
# 529                             2               1                   5
# 530                             2               1                   8
# 585                             0               0                   3
# 586                             0               0                  12
# 691                             1               1                   5
# 692                             1               1                   8
# 693                             1               1                   5
# ...                           ...             ...                 ...
# 537026                          3               0                   5
# 537027                          3               0                  12
# 537028                          3               0                  14
# 537029                          3               0                   5
# 537030                          3               0                   8
# 537031                          3               0                   8
# 537032                          3               0                   1
# 537033                          3               0                   1
# 537034                          3               0                   5
# 537035                          3               0                   8
# 537036                          3               0                   1
# 537037                          3               0                   5
# 537038                          3               0                   8
# 537039                          3               0                   1
# 537040                          3               0                   3
# 537041                          3               0                   5
# 537042                          3               0                   5
# 537043                          3               0                   1
# 537044                          3               0                   1
# 537045                          3               0                   5
# 537087                          0               0                   8
# 537088                          0               0                   1
# 537089                          0               0                   3
# 537090                          0               0                   8
# 537091                          0               0                   3
# 537092                          0               0                   5
# 537288                          3               0                   8
# 537289                          3               0                   8
# 537290                          3               0                   7
# 537291                          3               0                   7
#
#         Product_Category_2  Product_Category_3  Purchase
# 47                    17.0                 NaN      6171
# 48                     2.0                 5.0     19327
# 49                    13.0                 NaN      8027
# 124                    NaN                 NaN      2230
# 125                    8.0                 NaN      6940
# 126                    6.0                14.0     15774
# 147                   16.0                 NaN       758
# 148                    8.0                 NaN      6904
# 149                   11.0                 NaN      8690
# 150                    8.0                 NaN      8624
# 151                   14.0                17.0      3904
# 163                    8.0                 NaN      7134
# 219                   14.0                17.0      8034
# 297                   16.0                 NaN      5878
# 298                    NaN                 NaN      5845
# 406                    8.0                17.0     11715
# 407                    NaN                 NaN      7973
# 454                   10.0                 NaN     10058
# 457                    2.0                15.0     15584
# 458                   11.0                 NaN      8775
# 459                    2.0                 NaN      7996
# 460                    9.0                 NaN      6889
# 461                    2.0                 3.0     11730
# 529                   15.0                 NaN      7193
# 530                   14.0                 NaN      5857
# 585                    4.0                 5.0     10930
# 586                   14.0                 NaN      1735
# 691                   14.0                 NaN      6954
# 692                    NaN                 NaN      9972
# 693                   14.0                 NaN      7041
# ...                    ...                 ...       ...
# 537026                 8.0                14.0      7020
# 537027                14.0                 NaN      1034
# 537028                16.0                 NaN     15229
# 537029                15.0                 NaN      7153
# 537030                13.0                 NaN      6178
# 537031                 NaN                 NaN      8143
# 537032                 2.0                11.0     11786
# 537033                16.0                 NaN     15450
# 537034                12.0                 NaN      7144
# 537035                14.0                 NaN      8066
# 537036                14.0                17.0      7967
# 537037                14.0                 NaN      7017
# 537038                14.0                 NaN      7846
# 537039                 2.0                 5.0      7887
# 537040                 4.0                12.0      8132
# 537041                14.0                 NaN      5142
# 537042                14.0                 NaN      1961
# 537043                 8.0                15.0     15583
# 537044                 2.0                15.0      4088
# 537045                 NaN                 NaN      8903
# 537087                 NaN                 NaN     10024
# 537088                16.0                 NaN     15721
# 537089                 4.0                 5.0     13252
# 537090                16.0                 NaN      8099
# 537091                 4.0                 5.0     10687
# 537092                 8.0                14.0      5336
# 537288                 NaN                 NaN      6197
# 537289                16.0                17.0      6187
# 537290                 NaN                 NaN     16335
# 537291                12.0                 NaN     12248
#
# [49348 rows x 12 columns]

# %% [markdown]
# ## Questão 1
#
# Quantas observações e quantas colunas há no dataset? Responda no formato de uma tuple `(n_observacoes, n_colunas)`.

# %%
def q1():
    statistics = (len(black_friday), len(black_friday.columns))
    return statistics

# %% [markdown]
# ## Questão 2
#
# Há quantas mulheres com idade entre 26 e 35 anos no dataset? Responda como um único escalar.

# %%
def q2():
    # Retorne aqui o resultado da questão 2.
    df_womans =  black_friday.loc[ black_friday['Age'] == '26-35'].loc[black_friday['Gender'] == 'F']
    # Deveria ser len(df_womans['User_ID'].unique()), mas o teste está incorreto
    return len(df_womans)

# %% [markdown]
# ## Questão 3
#
# Quantos usuários únicos há no dataset? Responda como um único escalar.

# %%
def q3():
    # Retorne aqui o resultado da questão 3.
    len_unique_users = len(black_friday['User_ID'].unique()) 
    return len_unique_users

# %% [markdown]
# ## Questão 4
#
# Quantos tipos de dados diferentes existem no dataset? Responda como um único escalar.

# %%
def q4():
    # Retorne aqui o resultado da questão 4.
    unique_types_len = len(black_friday.dtypes.unique())
    return unique_types_len

# %% [markdown]
# ## Questão 5
#
# Qual porcentagem dos registros possui ao menos um valor null (`None`, `ǸaN` etc)? Responda como um único escalar entre 0 e 1.

# %%
def q5():
    # Retorne aqui o resultado da questão 5.
    without_nan = len(black_friday) - len(black_friday.dropna())
    total = without_nan / len(black_friday)
    return total

# %% [markdown]
# ## Questão 6
#
# Quantos valores null existem na variável (coluna) com o maior número de null? Responda como um único escalar.

# %%
def q6():
    # Retorne aqui o resultado da questão 6.
    nan_values = black_friday.isnull().sum()
    nan_max = nan_values.max()
    return nan_max

# %% [markdown]
# ## Questão 7
#
# Qual o valor mais frequente (sem contar nulls) em `Product_Category_3`? Responda como um único escalar.

# %%
def q7():
    # Retorne aqui o resultado da questão 7.
    diferents_values = black_friday['Product_Category_3'].value_counts()
    most_common = diferents_values.idxmax()
    return most_common

# %% [markdown]
# ## Questão 8
#
# Qual a nova média da variável (coluna) `Purchase` após sua normalização? Responda como um único escalar.

# %%
def q8():
    # Retorne aqui o resultado da questão 8.
    max_value = black_friday['Purchase'].max()
    min_value = black_friday['Purchase'].min()
    normalize_purchase = (black_friday['Purchase'] - min_value) / (max_value - min_value)
    mean = normalize_purchase.mean()
    return mean

# %% [markdown]
# ## Questão 9
#
# Quantas ocorrências entre -1 e 1 inclusive existem da variáel `Purchase` após sua padronização? Responda como um único escalar.

# %%
def q9():
    # Retorne aqui o resultado da questão 9.
    max_value = black_friday['Purchase'].max()
    min_value = black_friday['Purchase'].min()
    normalize_purchase = (black_friday['Purchase']-black_friday['Purchase'].mean())/black_friday['Purchase'].std()
    count = normalize_purchase.loc[ normalize_purchase >= -1 ].loc[ normalize_purchase <= 1 ]
    return len(count)

# %% [markdown]
# ## Questão 10
#
# Podemos afirmar que se uma observação é null em `Product_Category_2` ela também o é em `Product_Category_3`? Responda com um bool (`True`, `False`).

# %%
def q10():
    # Retorne aqui o resultado da questão 10.
    first_null = black_friday.loc[ black_friday.isnull()['Product_Category_2'] == True] 
    both_null = first_null.loc[ first_null.isnull()['Product_Category_3'] == False]

    if (both_null['User_ID'].count() == 0):
        isTrue = True 
    else: isTrue = False

    return isTrue
